# %% [markdown]
# # load Imagenet Tiny Dataset

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Out:
# --2021-12-16 17:17:25--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  38.1MB/s    in 7.0s
#
# 2021-12-16 17:17:32 (34.0 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]

# %%
# !unzip -q tiny-imagenet-200.zip

# %%
cd tiny-imagenet-200/
# Out:
# /content/tiny-imagenet-200

# %%
cd train
# Out:
# /content/tiny-imagenet-200/train

# %%
cd ..
# Out:
# /content/tiny-imagenet-200/train

# %%
cd n09256479
# Out:
# /content/tiny-imagenet-200/train/n09256479

# %%
ls
# Out:
# images/  n09256479_boxes.txt

# %%
cd images
# Out:
# /content/tiny-imagenet-200/train/n09256479/images

# %%
ls
# Out:
# n09256479_0.JPEG    n09256479_212.JPEG  n09256479_325.JPEG  n09256479_438.JPEG
# n09256479_100.JPEG  n09256479_213.JPEG  n09256479_326.JPEG  n09256479_439.JPEG
# n09256479_101.JPEG  n09256479_214.JPEG  n09256479_327.JPEG  n09256479_43.JPEG
# n09256479_102.JPEG  n09256479_215.JPEG  n09256479_328.JPEG  n09256479_440.JPEG
# n09256479_103.JPEG  n09256479_216.JPEG  n09256479_329.JPEG  n09256479_441.JPEG
# n09256479_104.JPEG  n09256479_217.JPEG  n09256479_32.JPEG   n09256479_442.JPEG
# n09256479_105.JPEG  n09256479_218.JPEG  n09256479_330.JPEG  n09256479_443.JPEG
# n09256479_106.JPEG  n09256479_219.JPEG  n09256479_331.JPEG  n09256479_444.JPEG
# n09256479_107.JPEG  n09256479_21.JPEG   n09256479_332.JPEG  n09256479_445.JPEG
# n09256479_108.JPEG  n09256479_220.JPEG  n09256479_333.JPEG  n09256479_446.JPEG
# n09256479_109.JPEG  n09256479_221.JPEG  n09256479_334.JPEG  n09256479_447.JPEG
# n09256479_10.JPEG   n09256479_222.JPEG  n09256479_335.JPEG  n09256479_448.JPEG
# ...

# %%
import cv2 
from google.colab.patches import cv2_imshow

#for i in range(0,20):
img = cv2.imread('n09256479_446.JPEG')
cv2_imshow (img)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F71F99B25D0>

# %%
cd ..
# Out:
# /content/tiny-imagenet-200/train/n01443537

# %%
ls
# Out:
# images/  n01443537_boxes.txt

# %% [markdown]
# # Daltonize Library for CVD Simulation

# %%
# !pip install daltonize

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
org_img=cv2.imread('1.jpg') 


simul_rgb_p = simulate(org_img, "p")
simul_rgb_d = simulate(org_img, "d")
simul_rgb_t = simulate(org_img, "t")

# %%
plt.figure(figsize=(40,40))
cv2_imshow(org_img)
cv2_imshow(simul_rgb_p)
cv2_imshow(simul_rgb_d)
cv2_imshow(simul_rgb_t)
# Out:
# <PIL.Image.Image image mode=RGB size=212x384 at 0x7F71F8433810>
# <PIL.Image.Image image mode=RGB size=212x384 at 0x7F71F842F6D0>
# <PIL.Image.Image image mode=RGB size=212x384 at 0x7F71F842F210>
# <PIL.Image.Image image mode=RGB size=212x384 at 0x7F71F842F4D0>
